# %%
import sum_polar_vector

a = [0, 1]
b = [90,1]
c = sum_polar_vector.sum_vector(a,b)
print(c)
# Out:
# [45.0, 1.4142135623730951]

# %%
import vector_fcn as vct
a = [0,1]
b = [60,1]
c = vct.sum_vect(a,b)   
vct.plt_vect([a,b,c])
